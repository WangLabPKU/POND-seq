# %%
library(DESeq2)
library(tidyverse)
library(airway) 
library(repr)
library(clusterProfiler)
library(DOSE)
library(org.Hs.eg.db)
library(enrichplot)
library(stringr)
# Out:
# Loading required package: S4Vectors
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: 'BiocGenerics'
#
#
# The following objects are masked from 'package:stats':
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from 'package:base':
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
#
# Attaching package: 'S4Vectors'
#
#
# The following objects are masked from 'package:base':
#
#     I, expand.grid, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomicRanges
#
# Loading required package: GenomeInfoDb
#
# ...

# %%
df_cluster <- read.csv("fig.13.csv")

# %%
ego1 <- enrichGO(gene = str_split((df_cluster %>% filter(group=="DelKH1/2"))$X,"\\.",n=2,simplify = TRUE)[,1],
                   OrgDb = org.Hs.eg.db, keyType = 'ENSEMBL', ont = "BP", pvalueCutoff = 0.05, qvalueCutoff = 0.1,readable = T)
ego2 <- enrichGO(gene = str_split((df_cluster %>% filter(group=="DelKH3/4"))$X,"\\.",n=2,simplify = TRUE)[,1],
                   OrgDb = org.Hs.eg.db, keyType = 'ENSEMBL', ont = "BP", pvalueCutoff = 0.05, qvalueCutoff = 0.1,readable = T)

# %%
ego3 <- enrichGO(gene = str_split((df_cluster %>% filter(group=="None"))$X,"\\.",n=2,simplify = TRUE)[,1],
                   OrgDb = org.Hs.eg.db, keyType = 'ENSEMBL', ont = "BP", pvalueCutoff = 0.05, qvalueCutoff = 0.1,readable = T)

# %%
write.csv(data.frame(simplify(ego1)),file="DelKH12_GOs.csv")
write.csv(data.frame(simplify(ego2)),file="DelKH34_GOs.csv")

# %%
write.csv(data.frame(simplify(ego3)),file="Other_GOs.csv")

# %%
?enrichGO
# Out:
# enrichGO            package:clusterProfiler            R Documentation
#
# s
# l.
#
# n:
#
#      GO Enrichment Analysis of a gene set. Given a vector of genes,
#      this function will return the enrichment GO categories after FDR
#      control.
#
# e:
#
#      enrichGO(
#        gene,
#        OrgDb,
#        keyType = "ENTREZID",
#        ont = "MF",
#        pvalueCutoff = 0.05,
#        pAdjustMethod = "BH",
#        universe,
#        qvalueCutoff = 0.2,
#        minGSSize = 10,
#        maxGSSize = 500,
#        readable = FALSE,
#        pool = FALSE
#      )
#
# s:
#
#     gene: a vector of entrez gene id.
#
#    OrgDb: OrgDb
#
#  keyType: keytype of input gene
#
#      ont: One of "BP", "MF", and "CC" subontologies, or "ALL" for all
#           three.
#
# pvalueCutoff: adjusted pvalue cutoff on enrichment tests to report
#
# pAdjustMethod: one of "holm", "hochberg", "hommel", "bonferroni", "BH",
#           "BY", "fdr", "none"
#
# ...

# %%
df_1 <-  read.csv("/home/gangx/data/HLF/260109/D0_not.txt",header = F)
df_2 <-  read.csv("/home/gangx/data/HLF/260109/D0_spe.txt",header = F)
df_3 <-  read.csv("/home/gangx/data/HLF/260109/DR1_spe.txt",header = F)
df_4 <-  read.csv("/home/gangx/data/HLF/260109/targets.txt",header = F)

# %%
ego1 <- enrichGO(gene = df_1$V1,
                   OrgDb = org.Hs.eg.db, keyType = 'ENSEMBL', ont = "BP", pvalueCutoff = 0.05, qvalueCutoff = 0.1,readable = T)
ego2 <- enrichGO(gene = df_2$V1,
                   OrgDb = org.Hs.eg.db, keyType = 'ENSEMBL', ont = "BP", pvalueCutoff = 0.05, qvalueCutoff = 0.1,readable = T)
ego3 <- enrichGO(gene = df_3$V1,
                   OrgDb = org.Hs.eg.db, keyType = 'ENSEMBL', ont = "BP", pvalueCutoff = 0.05, qvalueCutoff = 0.1,readable = T)

# %%
write.csv(data.frame(simplify(ego1)),file="/home/gangx/data/HLF/260109/D0_not_GOs.csv")
write.csv(data.frame(simplify(ego2)),file="/home/gangx/data/HLF/260109/D0_spe_GOs.csv")
write.csv(data.frame(simplify(ego3)),file="/home/gangx/data/HLF/260109/DR1_spe_GOs.csv")
# Out:
# #
# # over-representation test
# #
# #...@organism 	 Homo sapiens
# #...@ontology 	 BP
# #...@keytype 	 ENSEMBL
# #...@gene 	 chr [1:95] "ENSG00000078369" "ENSG00000117676" "ENSG00000121753" ...
# #...pvalues adjusted by 'BH' with cutoff <0.05
# #...2 enriched terms found
# 'data.frame':	2 obs. of  9 variables:
#  $ ID         : chr  "GO:0030900" "GO:0045217"
#  $ Description: chr  "forebrain development" "cell-cell junction maintenance"
#  $ GeneRatio  : chr  "9/80" "3/80"
#  $ BgRatio    : chr  "413/20973" "20/20973"
#  $ pvalue     : num  2.75e-05 5.81e-05
#  $ p.adjust   : num  0.0414 0.0437
#  $ qvalue     : num  0.0379 0.0401
#  $ geneID     : chr  "SLC2A1/INHBB/CXCR4/GBX2/BNIP3/EFNA2/SEMA6B/NUMBL/WNT7B" "F2R/WHRN/PARD6A"
#  $ Count      : int  9 3
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
# ...

# %%
df_co <- read.csv("/home/gangx/data/HLF/251221/fuzzy_output.csv")

# %%
bg_gene <-  str_split(df_co$X,"\\.",n=2,simplify = TRUE)[,1]

# %%
ego1 <- enrichGO(gene = str_split((df_co %>% filter(coculture_cluster==1))$X,"\\.",n=2,simplify = TRUE)[,1], universe = bg_gene,
                   OrgDb = org.Hs.eg.db, keyType = 'ENSEMBL', ont = "BP", pvalueCutoff = 0.05, qvalueCutoff = 0.1,readable = T)
ego2 <- enrichGO(gene = str_split((df_co %>% filter(coculture_cluster==2))$X,"\\.",n=2,simplify = TRUE)[,1], universe = bg_gene,
                   OrgDb = org.Hs.eg.db, keyType = 'ENSEMBL', ont = "BP", pvalueCutoff = 0.05, qvalueCutoff = 0.1,readable = T)
ego3 <- enrichGO(gene = str_split((df_co %>% filter(coculture_cluster==3))$X,"\\.",n=2,simplify = TRUE)[,1], universe = bg_gene,
                   OrgDb = org.Hs.eg.db, keyType = 'ENSEMBL', ont = "BP", pvalueCutoff = 0.05, qvalueCutoff = 0.1,readable = T)
ego4 <- enrichGO(gene = str_split((df_co %>% filter(coculture_cluster==4))$X,"\\.",n=2,simplify = TRUE)[,1], universe = bg_gene,
                   OrgDb = org.Hs.eg.db, keyType = 'ENSEMBL', ont = "BP", pvalueCutoff = 0.05, qvalueCutoff = 0.1,readable = T)
ego5 <- enrichGO(gene = str_split((df_co %>% filter(coculture_cluster==5))$X,"\\.",n=2,simplify = TRUE)[,1], universe = bg_gene,
                   OrgDb = org.Hs.eg.db, keyType = 'ENSEMBL', ont = "BP", pvalueCutoff = 0.05, qvalueCutoff = 0.1,readable = T)
ego6 <- enrichGO(gene = str_split((df_co %>% filter(coculture_cluster==6))$X,"\\.",n=2,simplify = TRUE)[,1], universe = bg_gene,
                   OrgDb = org.Hs.eg.db, keyType = 'ENSEMBL', ont = "BP", pvalueCutoff = 0.05, qvalueCutoff = 0.1,readable = T)

# %%
write.csv(data.frame(simplify(ego1)),file="/home/gangx/data/HLF/251221/fuzzy_1_GOs.csv")
write.csv(data.frame(simplify(ego2)),file="/home/gangx/data/HLF/251221/fuzzy_2_GOs.csv")
write.csv(data.frame(simplify(ego3)),file="/home/gangx/data/HLF/251221/fuzzy_3_GOs.csv")
write.csv(data.frame(simplify(ego4)),file="/home/gangx/data/HLF/251221/fuzzy_4_GOs.csv")
write.csv(data.frame(simplify(ego5)),file="/home/gangx/data/HLF/251221/fuzzy_5_GOs.csv")
write.csv(data.frame(simplify(ego6)),file="/home/gangx/data/HLF/251221/fuzzy_6_GOs.csv")

# %%
df_co$ENSEMBL <-  str_split(df_co$X,"\\.",n=2,simplify = TRUE)[,1]

# %%
gene.df <- bitr(df_co$ENSEMBL,
            fromType = "ENSEMBL",
            toType = c("SYMBOL","ENTREZID"),
            OrgDb = org.Hs.eg.db)
df_co_merge=merge(df_co,gene.df,by.y="ENSEMBL",by.x="ENSEMBL")
# Out:
# 'select()' returned 1:many mapping between keys and columns
#
# Warning message in bitr(df_co$ENSEMBL, fromType = "ENSEMBL", toType = c("SYMBOL", :
# "15.58% of input gene IDs are fail to map..."

# %%
(df_co %>% filter(coculture_cluster==1))$ENTREZID
# Out:
# NULL

# %%
eKEGG1 <- enrichKEGG(gene = (df_co_merge %>% filter(coculture_cluster==1))$ENTREZID, universe = df_co_merge$ENTREZID,
                    organism = "hsa", keyType = 'kegg', pvalueCutoff = 0.05, qvalueCutoff = 0.1)
eKEGG2 <- enrichKEGG(gene = (df_co_merge %>% filter(coculture_cluster==2))$ENTREZID, universe = df_co_merge$ENTREZID,
                    organism = "hsa", keyType = 'kegg', pvalueCutoff = 0.05, qvalueCutoff = 0.1)
eKEGG3 <- enrichKEGG(gene = (df_co_merge %>% filter(coculture_cluster==3))$ENTREZID, universe = df_co_merge$ENTREZID,
                    organism = "hsa", keyType = 'kegg', pvalueCutoff = 0.05, qvalueCutoff = 0.1)
eKEGG4 <- enrichKEGG(gene = (df_co_merge %>% filter(coculture_cluster==4))$ENTREZID, universe = df_co_merge$ENTREZID,
                    organism = "hsa", keyType = 'kegg', pvalueCutoff = 0.05, qvalueCutoff = 0.1)
eKEGG5 <- enrichKEGG(gene = (df_co_merge %>% filter(coculture_cluster==5))$ENTREZID, universe = df_co_merge$ENTREZID,
                    organism = "hsa", keyType = 'kegg', pvalueCutoff = 0.05, qvalueCutoff = 0.1)
eKEGG6 <- enrichKEGG(gene = (df_co_merge %>% filter(coculture_cluster==6))$ENTREZID, universe = df_co_merge$ENTREZID,
                    organism = "hsa", keyType = 'kegg', pvalueCutoff = 0.05, qvalueCutoff = 0.1)

# %%
write.csv(data.frame(eKEGG1),file="/home/gangx/data/HLF/251221/fuzzy_1_KEGGs.csv")
write.csv(data.frame(eKEGG2),file="/home/gangx/data/HLF/251221/fuzzy_2_KEGGs.csv")
write.csv(data.frame(eKEGG3),file="/home/gangx/data/HLF/251221/fuzzy_3_KEGGs.csv")
write.csv(data.frame(eKEGG4),file="/home/gangx/data/HLF/251221/fuzzy_4_KEGGs.csv")
write.csv(data.frame(eKEGG5),file="/home/gangx/data/HLF/251221/fuzzy_5_KEGGs.csv")
write.csv(data.frame(eKEGG6),file="/home/gangx/data/HLF/251221/fuzzy_6_KEGGs.csv")

# %%
df_yth <- read.csv("/home/gangx/data/HLF/260109/fuzzy_targets_output.csv")

# %%
bg_gene <-  str_split(df_yth$X,"\\.",n=2,simplify = TRUE)[,1]

# %%
ego1 <- enrichGO(gene = str_split((df_yth %>% filter(coculture_cluster==1))$X,"\\.",n=2,simplify = TRUE)[,1], universe = bg_gene,
                   OrgDb = org.Hs.eg.db, keyType = 'ENSEMBL', ont = "BP", pvalueCutoff = 0.05, qvalueCutoff = 0.1,readable = T)
ego2 <- enrichGO(gene = str_split((df_yth %>% filter(coculture_cluster==2))$X,"\\.",n=2,simplify = TRUE)[,1], universe = bg_gene,
                   OrgDb = org.Hs.eg.db, keyType = 'ENSEMBL', ont = "BP", pvalueCutoff = 0.05, qvalueCutoff = 0.1,readable = T)
ego3 <- enrichGO(gene = str_split((df_yth %>% filter(coculture_cluster==3))$X,"\\.",n=2,simplify = TRUE)[,1], universe = bg_gene,
                   OrgDb = org.Hs.eg.db, keyType = 'ENSEMBL', ont = "BP", pvalueCutoff = 0.05, qvalueCutoff = 0.1,readable = T)
ego4 <- enrichGO(gene = str_split((df_yth %>% filter(coculture_cluster==4))$X,"\\.",n=2,simplify = TRUE)[,1], universe = bg_gene,
                   OrgDb = org.Hs.eg.db, keyType = 'ENSEMBL', ont = "BP", pvalueCutoff = 0.05, qvalueCutoff = 0.1,readable = T)
ego5 <- enrichGO(gene = str_split((df_yth %>% filter(coculture_cluster==5))$X,"\\.",n=2,simplify = TRUE)[,1], universe = bg_gene,
                   OrgDb = org.Hs.eg.db, keyType = 'ENSEMBL', ont = "BP", pvalueCutoff = 0.05, qvalueCutoff = 0.1,readable = T)
ego6 <- enrichGO(gene = str_split((df_yth %>% filter(coculture_cluster==6))$X,"\\.",n=2,simplify = TRUE)[,1], universe = bg_gene,
                   OrgDb = org.Hs.eg.db, keyType = 'ENSEMBL', ont = "BP", pvalueCutoff = 0.05, qvalueCutoff = 0.1,readable = T)

# %%
write.csv(data.frame(simplify(ego1)),file="/home/gangx/data/HLF/260109/fuzzy_1_targets_GOs.csv")
write.csv(data.frame(simplify(ego2)),file="/home/gangx/data/HLF/260109/fuzzy_2_targets_GOs.csv")
write.csv(data.frame(simplify(ego3)),file="/home/gangx/data/HLF/260109/fuzzy_3_targets_GOs.csv")
write.csv(data.frame(simplify(ego4)),file="/home/gangx/data/HLF/260109/fuzzy_4_targets_GOs.csv")
write.csv(data.frame(simplify(ego5)),file="/home/gangx/data/HLF/260109/fuzzy_5_targets_GOs.csv")
write.csv(data.frame(simplify(ego6)),file="/home/gangx/data/HLF/260109/fuzzy_6_targets_GOs.csv")

# %%
df_yth$ENSEMBL <-  str_split(df_yth$X,"\\.",n=2,simplify = TRUE)[,1]
gene.df <- bitr(df_yth$ENSEMBL,
            fromType = "ENSEMBL",
            toType = c("SYMBOL","ENTREZID"),
            OrgDb = org.Hs.eg.db)
df_yth_merge=merge(df_yth,gene.df,by.y="ENSEMBL",by.x="ENSEMBL")
# Out:
# 'select()' returned 1:many mapping between keys and columns
#
# Warning message in bitr(df_yth$ENSEMBL, fromType = "ENSEMBL", toType = c("SYMBOL", :
# "4.14% of input gene IDs are fail to map..."

# %%
eKEGG1 <- enrichKEGG(gene = (df_yth_merge %>% filter(coculture_cluster==1))$ENTREZID, universe = df_yth_merge$ENTREZID,
                    organism = "hsa", keyType = 'kegg', pvalueCutoff = 0.05, qvalueCutoff = 0.1)
eKEGG2 <- enrichKEGG(gene = (df_yth_merge %>% filter(coculture_cluster==2))$ENTREZID, universe = df_yth_merge$ENTREZID,
                    organism = "hsa", keyType = 'kegg', pvalueCutoff = 0.05, qvalueCutoff = 0.1)
eKEGG3 <- enrichKEGG(gene = (df_yth_merge %>% filter(coculture_cluster==3))$ENTREZID, universe = df_yth_merge$ENTREZID,
                    organism = "hsa", keyType = 'kegg', pvalueCutoff = 0.05, qvalueCutoff = 0.1)
eKEGG4 <- enrichKEGG(gene = (df_yth_merge %>% filter(coculture_cluster==4))$ENTREZID, universe = df_yth_merge$ENTREZID,
                    organism = "hsa", keyType = 'kegg', pvalueCutoff = 0.05, qvalueCutoff = 0.1)
eKEGG5 <- enrichKEGG(gene = (df_yth_merge %>% filter(coculture_cluster==5))$ENTREZID, universe = df_yth_merge$ENTREZID,
                    organism = "hsa", keyType = 'kegg', pvalueCutoff = 0.05, qvalueCutoff = 0.1)
eKEGG6 <- enrichKEGG(gene = (df_yth_merge %>% filter(coculture_cluster==6))$ENTREZID, universe = df_yth_merge$ENTREZID,
                    organism = "hsa", keyType = 'kegg', pvalueCutoff = 0.05, qvalueCutoff = 0.1)

# %%
write.csv(data.frame(eKEGG1),file="/home/gangx/data/HLF/260109/fuzzy_1_targets_KEGGs.csv")
write.csv(data.frame(eKEGG2),file="/home/gangx/data/HLF/260109/fuzzy_2_targets_KEGGs.csv")
write.csv(data.frame(eKEGG3),file="/home/gangx/data/HLF/260109/fuzzy_3_targets_KEGGs.csv")
write.csv(data.frame(eKEGG4),file="/home/gangx/data/HLF/260109/fuzzy_4_targets_KEGGs.csv")
write.csv(data.frame(eKEGG5),file="/home/gangx/data/HLF/260109/fuzzy_5_targets_KEGGs.csv")
write.csv(data.frame(eKEGG6),file="/home/gangx/data/HLF/260109/fuzzy_6_targets_KEGGs.csv")
